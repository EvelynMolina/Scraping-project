# %%
from bs4 import BeautifulSoup
from threading import Thread
from time import perf_counter, sleep
import math
import pandas as pd
import queue
import requests

url = 'https://www.conocerbarcelona.com/actividades'

# %% [markdown]
# # Scraping Project
#
# The main objective of the following code is to (i) generate a database from web scraping with all the tours available in Barcelona. The source of information is "https://www.conocerbarcelona.com/actividades" and (ii) generate concurrent HTTP requests while scraping using queue and threading, to measure time savings in programming.

# %%
get_next(soup)
# Out:
# 'https://www.conocerbarcelona.com/actividades/2/'

# %%
#Choosing the information to be extracted

## 1. Returns the title of each tour in Barcelona
def get_title(soup):    
    return [s.get_text().replace("\n"," ").replace("\ue9ce","").replace("\xa0","").replace("   "," ") 
            for s in soup.select("h3.title--activity-card")]

## 2. Returns the description of each tour
def get_description(soup):
    """ Returns the description of the tour"""
    return [s.get_text().replace("\n"," ").replace("\ue9ce","").replace("\xa0","").replace("   "," ") 
            for s in soup.select("div.m-card__text")]

## 3. Returns the price of each tour
def get_price(soup):    
    """ Returns the price of the tour"""
    return [s.get_text().replace("\n"," ").replace("\ue9ce","").replace("\xa0","").replace("   "," ") 
            for s in soup.select("div.o-container-group")]

## 4. Returns the url of each page
def get_next(soup):
    try:
        return ("{}{}".format ('https://www.conocerbarcelona.com',(soup.select('a.next-element')[0]['href'])))
    except IndexError:
        return None
    
## 5. Using beautifulsoup 
def get_soup(url):
    res = requests.get(url)
    return BeautifulSoup(res.text,'lxml')

## 6. TEST: Extract all the information from all pages without using the library(queue) to estimate time 
# %time
def agregated(url):
    titles = []
    description = []
    price= []
    while url:
        soup = get_soup(url)
        titles += get_title(soup)
        description += get_description(soup)
        price += get_price(soup)
        url = get_next(soup)
    return pd.concat([(pd.DataFrame(titles)),(pd.DataFrame(description)),(pd.DataFrame(price))], ignore_index=True, axis=1)
# Out:
# CPU times: user 2 µs, sys: 1e+03 ns, total: 3 µs
# Wall time: 6.91 µs

# %%
 ## 7. Estimated time
# %time
Final=agregated(url)
Final.columns=["Tour", "Description", "Price"]
Final
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 8.11 µs
#                                                  Tour  \
# 0           Entrada a la Sagrada Familia sin colas
# 1                 Free tour por Barcelona ¡Gratis!
# 2                    Tour de Barcelona al completo
# 3        Tour de los misterios y leyendas de Barce...
# 4          Sagrada Familia con subida a las torres
# 5        Free tour de Gaudí y la Barcelona moderni...
# 6                                Tarjeta Hola BCN!
# 7                Visita guiada por el Parque Güell
# 8        Excursión a Girona, Figueres y Museo Dalí
# 9        Excursión a Montserrat con tren cremaller...
# 10                                   Camp Nou Tour
# 11                  Autobús turístico de Barcelona
# 12       Tour nocturno por Barcelona y Fuente Mági...
# 13                          Excursión a Montserrat
# 14        Andalucía y Costa Mediterránea en 6 días
# 15          Tour privado por Barcelona ¡Tú eliges!
# 16          Visita de la Sagrada Familia sin colas
# 17              Entrada a la Casa Batlló sin colas
# 18                                  Barcelona Card
# 19       Entrada al parque de atracciones del Tibi...
# 20                 Tour en bicicleta por Barcelona
# 21          Espectáculo en el Palacio del Flamenco
# 22         Excursión a PortAventura y Ferrari Land
# 23            Girona, escenario de Juego de Tronos
# 24          Oferta: Parque Güell + Sagrada Familia
# 25                  Tour por la Barcelona medieval
# 26                          Teleférico de Montjuïc
# 27       Visita guiada al Palau de la Música Catal...
# 28                            Entrada a La Pedrera
# 29       Tour por las bodegas del Penedés y cavas ...
# ..                                                ...
# 65                Visita guiada por la Casa Vicens
# 66                        Excursión a los Pirineos
# 67                Excursión a Cardona y Montserrat
# 68       Visita nocturna y espectáculo en La Pedre...
# 69       Tour por el barrio Gótico, el Museo Picas...
# 70           Tour de 5 días por Andalucía y Toledo
# 71           Entradas para Maestros de la Guitarra
# 72       Excursión al parque acuático PortAventura...
# 73               Excursión privada desde Barcelona
# 74                       Barcelona Pass Modernista
# 75          Excursión a Montserrat de día completo
# 76       Tour en bicicleta eléctrica por Barcelona
# 77                         Entrada a Colonia Güell
# 78                     Tour en Vespa por Barcelona
# 79                   Visita guiada por el Camp Nou
# 80                Tour por las maravillas de Gaudí
# 81               Excursión a Lloret y Tossa de Mar
# 82                      Excursión a la Costa Brava
# 83                              Articket Barcelona
# 84         Visita guiada por el barrio de El Raval
# 85       Paseo en barco por las playas de Barcelon...
# 86                     Tour de La Catedral del Mar
# 87       Tour por el Barrio Gótico y el Palau Güel...
# 88       Tour por Barcelona en Ferrari o Lamborghi...
# 89                  Alquiler de motos en Barcelona
# 90           Visita guiada por la Puerta del Ángel
# 91              Tour de los fantasmas de Barcelona
# 92                      Tour en moto por Barcelona
# 93                Entrada a Catalunya en Miniatura
# 94                                                NaN
#
#                                           Description              Price
# 0      Visitar el símbolo de Barcelona es una expe...              18 €
# 1    Recorre el centro histórico de la Ciudad Cond...          ¡Gratis!
# 2      ¿Quieres conocer lo mejor de Barcelona en u...              51 €
# 3      Descubre con esta ruta nocturna por Barcelo...              12 €
# 4      En esta visita no solo nos adentraremos en ...    por coche 39 €
# 5    Adéntrate en el corazón modernista de Barcelo...              42 €
# 6      La tarjeta Hola BCN! permite el uso ilimita...          ¡Gratis!
# 7      El Parque Güell es una de las obras más rep...              15 €
# 8      En este tour conoceremos dos de las ciudade...              24 €
# 9      Con 1.236 metros de altura, Montserrat es u...              78 €
# 10     En este tour conoceréis el estadio del mejo...              55 €
# 11     Los autobuses turísticos cuentan con tres r...              29 €
# 12     Descubre por qué Barcelona tiene un encanto...              30 €
# 13     Napoleón, los nazis, la patrulla de “El Min...              44 €
# 14     Descubre las ciudades más emblemáticas de A...              54 €
# 15     Reservando nuestra visita guiada privada te...             780 €
# 16     Si hay un lugar que nadie puede perderse al...    por grupo 90 €
# 17     Sumérgete en el simbolismo gaudiano visitan...              40 €
# 18     La tarjeta Barcelona Card proporciona acces...            29,5 €
# 19     Disfruta de un día inolvidable en el parque...              42 €
# 20     Descubre la magia de la Ciudad Condal de un...            12,7 €
# 21     Disfruta del mejor espectáculo de flamenco ...              18 €
# 22     Pasa un día diferente disfrutando de las at...              35 €
# 23     Siéntete como un Lannister o un Stark en es...              69 €
# 24     Déjate seducir por dos de las principales a...              55 €
# 25     La basílica de Santa María del Mar, popular...              69 €
# 26     Asciende a la cima de Montjuïc, la montaña ...              12 €
# 27     Visita uno de los edificios más emblemático...            12,7 €
# 28     Adéntrate en el mundo de la arquitectónico ...              20 €
# 29     En esta excursión nos acercaremos a la regi...              22 €
# ..                                                ...                ...
# 65     Adéntrate en los orígenes de la arquitectur...              10 €
# 66     Aléjate de la vorágine urbana y disfruta de...              30 €
# 67     Viaja hasta el siglo IX y adéntrate en los ...              73 €
# 68     Vive una experiencia única con un espectácu...              95 €
# 69     Recorre Barcelona desde su época medieval h...              34 €
# 70     Déjate cautivar por los contrastes entre Or...              35 €
# 71     Emociónate con la guitarra española y flame...             790 €
# 72     Disfruta de un día completo en lasatraccion...              23 €
# 73     La Costa Brava, Tossa de Mar, Montserrat… D...              40 €
# 74     La tarjeta Barcelona Pass Modernista permit...   por grupo 245 €
# 75     Peregrinos, Leonardo Da Vinci, los nazis… D...              81 €
# 76     Recorrer Barcelona en bici es una experienc...              79 €
# 77     Adéntrate en una de las obras arquitectónic...              33 €
# 78     Súbete a bordo de nuestras Vespas y recorre...               9 €
# 79     Recorre junto a un guía experto en fútbol e...    por grupo 45 €
# 80     En este tour visitaremos el Parque Güell, l...              50 €
# 81     Contrapuestos y complementarios, en este to...              77 €
# 82     En este tour descubriréis los lugares más r...              55 €
# 83     La tarjeta Articket Barcelona te permite ac...              84 €
# 84     En cada esquina de El Raval se puede apreci...              30 €
# 85     En este tour admiraremos el litoral de Barc...              15 €
# 86     Adéntrate en la Barcelona medieval visitand...              18 €
# 87     Descubre los secretos del Barrio Gótico de ...              14 €
# 88     ¿Te apasiona el mundo del motor? Vive la ex...              30 €
# 89     Recorre todos los barrios de Barcelona con ...   por grupo 119 €
# 90     En esta visita guiada recorreremos una de l...              38 €
# 91     Merodean errantes, vagando atormentados por...            14,5 €
# 92     ¡Disfruta del encanto de Barcelona en una c...              12 €
# 93     ¿Quieres ver los monumentos más famosos de ...              54 €
# 94                                                NaN            11,5 €
#
# [95 rows x 3 columns]

# %%
ScrapingProjectDB = Final.to_csv('TourInformationBarcelona.csv', index=False)

# %%
START_URL = 'https://www.conocerbarcelona.com/actividades'
columns = ["Tour" ,"Description", "Price"]
result = pd.DataFrame(columns=columns)
my_queue = queue.Queue()

def make_urls2():
    url_list2 = []
    url_list2.append(START_URL)
    for page in range(2, 6):
        url_list2.append(START_URL + "/" + str(page) +"/")
    return url_list2
    
## Defining queues and threads

def worker(url, queue):
    
    soup = BeautifulSoup(requests.get(url).text, 'html.parser')

    titles = []
    description = []
    prices = []
        # Find all tour titles
    for h3 in soup.select("h3.title--activity-card"):
        titles.append(h3.text.replace("\n"," ").replace("\ue9ce","").replace("\xa0","").replace("   "," "))     
        # Find all descriptions
    for div in soup.select("div.m-card__text"):
        description.append(div.text.replace("\n"," ").replace("\ue9ce","").replace("\xa0","").replace("   "," "))
        # Find all tour prices       
    for div in soup.select("div.o-container-group"):
        prices.append(div.text.replace("\n"," ").replace("\ue9ce","").replace("\xa0","").replace("   "," "))
    
    queue.put(list(zip(titles, description, prices)))
    
urls = make_urls2()
all_threads = []
for url in urls:
    t = Thread(target=worker, args=(url, my_queue))
    t.start()
    all_threads.append(t)
    
# %time
result_count = 0
while result_count < len(urls):
    data = my_queue.get()
    result = result.append(pd.DataFrame(data, columns=columns))
    result_count += 1
# Out:
# CPU times: user 3 µs, sys: 0 ns, total: 3 µs
# Wall time: 5.96 µs

# %%
 ## The CPU time decreases considerably when using queues and threads!

# %%
FINAL = pd.DataFrame(result)
FINAL
# Out:
#                                                  Tour  \
# 0              Paseo en catamarán por el Port Vell
# 1         Cena y espectáculo en el Tablao Cordobés
# 2          Tour en 4x4 por los viñedos del Penedés
# 3                       Visita guiada por Sant Pau
# 4                   Tour fotográfico por Barcelona
# 5                Tour de compras a La Roca Village
# 6        Visita guiada por la Fábrica de Estrella ...
# 7                  Montserrat por libre en autobús
# 8                         Entrada a la Casa Vicens
# 9                      Entrada al Zoo de Barcelona
# 10                    Tour de La Sombra del Viento
# 11                     Tour de tapas por Barcelona
# 12       Visita guiada por el Gran Teatro del Lice...
# 13         Visita guiada por la Casa de les Punxes
# 14            Entrada para Gaudí Exhibition Center
# 15        Barcelona Night Card ¡Discotecas gratis!
# 16                Entrada al Gran Teatro del Liceo
# 17                  Paseo a caballo por Montserrat
# 18                   Paseo en velero por Barcelona
# 19            Paseo en velero clásico al atardecer
# 0                    Visita guiada por el Camp Nou
# 1                 Tour por las maravillas de Gaudí
# 2                Excursión a Lloret y Tossa de Mar
# 3                       Excursión a la Costa Brava
# 4                               Articket Barcelona
# 5          Visita guiada por el barrio de El Raval
# 6        Paseo en barco por las playas de Barcelon...
# 7                      Tour de La Catedral del Mar
# 8        Tour por el Barrio Gótico y el Palau Güel...
# 9        Tour por Barcelona en Ferrari o Lamborghi...
# ..                                                ...
# 9        Excursión a Montserrat con tren cremaller...
# 10                                   Camp Nou Tour
# 11                  Autobús turístico de Barcelona
# 12       Tour nocturno por Barcelona y Fuente Mági...
# 13                          Excursión a Montserrat
# 14        Andalucía y Costa Mediterránea en 6 días
# 15          Tour privado por Barcelona ¡Tú eliges!
# 16          Visita de la Sagrada Familia sin colas
# 17              Entrada a la Casa Batlló sin colas
# 18                                  Barcelona Card
# 0        Tour de tapas por los mercados y bares de...
# 1        Excursión a Montserrat, Sitges y Bodegas ...
# 2          Fiesta en catamarán Sensation Barcelona
# 3        Tapas por el Mercado de La Boquería y San...
# 4            Paseo en goleta y visita a una bodega
# 5                    Paseo en goleta por Barcelona
# 6                 Visita guiada por la Casa Vicens
# 7                         Excursión a los Pirineos
# 8                 Excursión a Cardona y Montserrat
# 9        Visita nocturna y espectáculo en La Pedre...
# 10       Tour por el barrio Gótico, el Museo Picas...
# 11           Tour de 5 días por Andalucía y Toledo
# 12           Entradas para Maestros de la Guitarra
# 13       Excursión al parque acuático PortAventura...
# 14               Excursión privada desde Barcelona
# 15                       Barcelona Pass Modernista
# 16          Excursión a Montserrat de día completo
# 17       Tour en bicicleta eléctrica por Barcelona
# 18                         Entrada a Colonia Güell
# 19                     Tour en Vespa por Barcelona
#
#                                           Description              Price
# 0      En este tour recorreremos la zona vieja de ...             7,5 €
# 1      Contágiate de los ritmos flamencos en el ta...              44 €
# 2      Recorre los famosos viñedos del Penedés en ...              74 €
# 3      El recinto modernista Sant Pau, declarado P...              27 €
# 4      Disfruta de Barcelona de una forma diferent...              45 €
# 5    Vive un día de shopping de lujo en La Roca Vi...              20 €
# 6      Conoce de primera mano la Fábrica de Estrel...               8 €
# 7      Esta excursión a Montserrat en autobús es i...              25 €
# 8      Diseñada por Antonio Gaudí, la Casa Vicens ...              16 €
# 9      Acércate al Zoológico de Barcelona, una peq...            21,4 €
# 10     Siente el placer por la literatura con este...              14 €
# 11     Patatas bravas, pan tumaca, croquetas, chor...              20 €
# 12     Recorre las principales salas del Gran Teat...              16 €
# 13     Descubre uno de los edificios más icónicos ...            12,5 €
# 14   Adéntrate en la mente del genio modernista An...              12 €
# 15     Con esta tarjeta podrás acceder de forma gr...              10 €
# 16     Puccini, Verdi, Mozart… El Gran Teatro de L...               9 €
# 17     ¿Te apetece visitar Montserrat de una forma...              89 €
# 18     Recorre la costa de Barcelona y admira el s...              79 €
# 19     Vive una experiencia inolvidable navegando ...              89 €
# 0      Recorre junto a un guía experto en fútbol e...              50 €
# 1      En este tour visitaremos el Parque Güell, l...              77 €
# 2      Contrapuestos y complementarios, en este to...              55 €
# 3      En este tour descubriréis los lugares más r...              84 €
# 4      La tarjeta Articket Barcelona te permite ac...              30 €
# 5      En cada esquina de El Raval se puede apreci...              15 €
# 6      En este tour admiraremos el litoral de Barc...              18 €
# 7      Adéntrate en la Barcelona medieval visitand...              14 €
# 8      Descubre los secretos del Barrio Gótico de ...              30 €
# 9      ¿Te apasiona el mundo del motor? Vive la ex...   por grupo 119 €
# ..                                                ...                ...
# 9      Con 1.236 metros de altura, Montserrat es u...              78 €
# 10     En este tour conoceréis el estadio del mejo...              55 €
# 11     Los autobuses turísticos cuentan con tres r...              29 €
# 12     Descubre por qué Barcelona tiene un encanto...              30 €
# 13     Napoleón, los nazis, la patrulla de “El Min...              44 €
# 14     Descubre las ciudades más emblemáticas de A...              54 €
# 15     Reservando nuestra visita guiada privada te...             780 €
# 16     Si hay un lugar que nadie puede perderse al...    por grupo 90 €
# 17     Sumérgete en el simbolismo gaudiano visitan...              40 €
# 18     La tarjeta Barcelona Card proporciona acces...            29,5 €
# 0      Sumérgete en la gastronomía catalana con es...              76 €
# 1      En esta excursión visitaremos las mejores b...              90 €
# 2      Disfruta de una fiesta en un catamarán y pa...              46 €
# 3      Descubre la gastronomía catalanacon este to...              36 €
# 4      Disfruta de un paseo en velero por la costa...             125 €
# 5      Relájate con un plácido paseo en goleta por...              10 €
# 6      Adéntrate en los orígenes de la arquitectur...              30 €
# 7      Aléjate de la vorágine urbana y disfruta de...              73 €
# 8      Viaja hasta el siglo IX y adéntrate en los ...              95 €
# 9      Vive una experiencia única con un espectácu...              34 €
# 10     Recorre Barcelona desde su época medieval h...              35 €
# 11     Déjate cautivar por los contrastes entre Or...             790 €
# 12     Emociónate con la guitarra española y flame...              23 €
# 13     Disfruta de un día completo en lasatraccion...              40 €
# 14     La Costa Brava, Tossa de Mar, Montserrat… D...   por grupo 245 €
# 15     La tarjeta Barcelona Pass Modernista permit...              81 €
# 16     Peregrinos, Leonardo Da Vinci, los nazis… D...              79 €
# 17     Recorrer Barcelona en bici es una experienc...              33 €
# 18     Adéntrate en una de las obras arquitectónic...               9 €
# 19     Súbete a bordo de nuestras Vespas y recorre...    por grupo 45 €
#
# [94 rows x 3 columns]
